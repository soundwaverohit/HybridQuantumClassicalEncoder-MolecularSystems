# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np

# %%
df= pd.read_csv("experiment_results.csv")
df.head(10)
# Out:
#         Experiment_run  true_energy  hybrid_model_energy
# 0  experiment_number_0   -74.963063            -7.494931
# 1  experiment_number_1   -74.963063            -3.068365
# 2  experiment_number_2   -74.963063            -3.438185
# 3  experiment_number_3   -74.963063            -3.623331
# 4  experiment_number_4   -74.963063            -1.007369
# 5  experiment_number_5   -74.963063            -2.608582
# 6  experiment_number_6   -74.963063            -3.517338
# 7  experiment_number_7   -74.963063            -2.754648
# 8  experiment_number_8   -74.963063            -2.423187
# 9  experiment_number_9   -74.963063            -2.944889

# %%
y= df['hybrid_model_energy']
x= [i for i in range(len(df))]
plt.plot(x,y)
plt.xlabel("Iterations")
plt.ylabel("Energy level")
plt.show()
